# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Height (cm)
X = np.array([[147,150,153,155,158,160,163,165,168,170,173,175,178,180,183]]).T
#Weight (kg)
y = np.array([[49,50,51,52,54,56,58,59,60,72,63,64,66,67,68]]).T

# %%
one = np.ones((X.shape[0], 1))
Xbar = np.concatenate((one, X), axis = 1)

print(Xbar)
# Out:
# [[  1. 147.]
#  [  1. 150.]
#  [  1. 153.]
#  [  1. 155.]
#  [  1. 158.]
#  [  1. 160.]
#  [  1. 163.]
#  [  1. 165.]
#  [  1. 168.]
#  [  1. 170.]
#  [  1. 173.]
#  [  1. 175.]
#  [  1. 178.]
#  [  1. 180.]
#  [  1. 183.]]

# %%
A = np.dot(Xbar.T, Xbar)
b = np.dot(Xbar.T, y)
w = np.dot(np.linalg.pinv(A), b)

w_0, w_1 = w[0], w[1]

print("A", A)

print("\n\nB", b)
# Out:
# A [[1.50000e+01 2.47800e+03]
#  [2.47800e+03 4.11152e+05]]
#
#
# B [[   889.]
#  [147918.]]

# %%
y1 = w_1 * 155 + w_0
y2 = w_1 * 160 + w_0

print('Input 155cm, true output 52kg, predicted output %.2fkg' % (y1))
print('Input 160cm, true output 63kg, predicted output %.2fkg' % (y2))
# Out:
# Input 155cm, true output 52kg, predicted output 53.24kg
# Input 160cm, true output 63kg, predicted output 56.20kg
# <ipython-input-9-942cb39cdd7a>:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('Input 155cm, true output 52kg, predicted output %.2fkg' % (y1))
# <ipython-input-9-942cb39cdd7a>:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('Input 160cm, true output 63kg, predicted output %.2fkg' % (y2))

# %%
from sklearn import datasets, linear_model
#Fit the model by Linear Regression
regr = linear_model.LinearRegression()
regr.fit(X, y)

print("Scikit-learn's solution: w_1 = ", regr.coef_[0], "w_0 = ", regr.intercept_)
print("Our solution: w_1 = ", w[1], "w_0 = ", w[0])
# Out:
# Scikit-learn's solution: w_1 =  [0.59068518] w_0 =  [-38.31452456]
# Our solution: w_1 =  [0.59068518] w_0 =  [-38.31452456]

# %%
#Optimizing linear regression using gradient descent
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.metrics import mean_squared_error

housing_data = fetch_california_housing()

Features = pd.DataFrame(housing_data.data, columns=housing_data.feature_names)
Target = pd.DataFrame(housing_data.target, columns=["Target"])
df = Features.join(Target)

# %%
df.corr()

#Remove outliers and scaling
df[['MedInc', 'Target']].describe()[1:]

df = df[df.Target < 3.5]
df = df[df.MedInc < 8]
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Target      0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude    Target
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
